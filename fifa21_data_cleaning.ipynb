# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishkabishtt/fifa21-data-cleaning/blob/main/fifa21_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

import kagglehub
import pandas as pd
import os

# %%
# Download the dataset using KaggleHub
path = kagglehub.dataset_download("yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:01<00:00, 4.19MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring/versions/2

# %%
# List all files in the downloaded folder
for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /root/.cache/kagglehub/datasets/yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring/versions/2/fifa21_raw_data.csv
# /root/.cache/kagglehub/datasets/yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring/versions/2/fifa21 raw data v2.csv

# %%
import pandas as pd

# Load the dataset using the correct filename
df = pd.read_csv(path + "/fifa21_raw_data.csv")  # or use "fifa21 raw data v2.csv" if preferred
df.head()
# Out:
# /tmp/ipython-input-2949989583.py:4: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + "/fifa21_raw_data.csv")  # or use "fifa21 raw data v2.csv" if preferred
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# ...

# %%
# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
print(df.columns.tolist())
# Out:
# ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits']

# %%
print(df.columns.tolist())
# Out:
# ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits']

# %%
df['name'] = df['name'].astype(str).str.strip().str.title()
df['longname'] = df['longname'].astype(str).str.strip().str.title()

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
print(df.columns.tolist())
# Out:
# ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits']

# %%
df['nationality'] = df['nationality'].astype(str).str.strip().str.title()
df['positions'] = df['positions'].astype(str).str.strip().str.upper()
df['foot'] = df['foot'].astype(str).str.strip().str.title()

# %%
for col in ['nationality', 'positions', 'foot']:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip().str.title()

# %%
# Convert numeric columns to proper types and handle missing values
numeric_cols = ['age', 'height', 'weight', 'vova', 'pot']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')
        df[col] = df[col].fillna(df[col].median())

# %%
if 'dob' in df.columns:
    df['dob'] = pd.to_datetime(df['dob'], errors='coerce')

# %%
df.drop_duplicates(inplace=True)

# %%
df['clean_status'] = 'Complete'

# %%
df.to_csv("fifa21_cleaned.csv", index=False)
print("Cleaned dataset saved as fifa21_cleaned.csv")
# Out:
# Cleaned dataset saved as fifa21_cleaned.csv

# %%
# Basic summary report with column checks
summary = {
    "Total Players": len(df),
    "Average Age": round(df['age'].mean(), 1) if 'age' in df.columns else "N/A",
    "Average Height (cm)": round(df['height'].mean(), 1) if 'height' in df.columns else "N/A",
    "Average Weight (kg)": round(df['weight'].mean(), 1) if 'weight' in df.columns else "N/A",
    "Average Potential": round(df['pot'].mean(), 1) if 'pot' in df.columns else "N/A",
    "Average Overall": round(df['vova'].mean(), 1) if 'vova' in df.columns else "N/A",
    "Unique Nationalities": df['nationality'].nunique() if 'nationality' in df.columns else "N/A",
    "Unique Clubs": df['club'].nunique() if 'club' in df.columns else "N/A"
}

print(summary)
# Out:
# {'Total Players': 18978, 'Average Age': np.float64(25.2), 'Average Height (cm)': nan, 'Average Weight (kg)': nan, 'Average Potential': np.float64(71.1), 'Average Overall': 'N/A', 'Unique Nationalities': 164, 'Unique Clubs': 'N/A'}

# %%
summary_df = pd.DataFrame([summary])
summary_df.to_csv("fifa21_summary.csv", index=False)

# %%
df
# Out:
#                                                photourl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            longname  \
# 0                      Lionel Messi
# 1      C. Ronaldo Dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar Da Silva Santos Jr.
# ...                             ...
# ...

# %%
from google.colab import files
files.download("fifa21_cleaned.csv")

# %%
# !pip install openpyxl

# %%
import pandas as pd

# Load your cleaned CSV
df = pd.read_csv("fifa21_cleaned.csv")

# Save as Excel file
df.to_excel("fifa21_cleaned.xlsx", index=False)
# Out:
# /tmp/ipython-input-959356761.py:4: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("fifa21_cleaned.csv")

# %%
from openpyxl import load_workbook
from openpyxl.styles import Alignment

# Load the Excel file
wb = load_workbook("fifa21_cleaned.xlsx")
ws = wb.active

# Set row height and wrap text for all rows
for row in ws.iter_rows():
    for cell in row:
        cell.alignment = Alignment(wrap_text=True)
    ws.row_dimensions[row[0].row].height = 30  # Adjust height as needed

# Save the updated Excel file
wb.save("fifa21_cleaned_formatted.xlsx")

# %%
from google.colab import files
files.download("fifa21_cleaned_formatted.xlsx")

# %%
import pandas as pd

# Load the formatted Excel file
df = pd.read_excel("fifa21_cleaned_formatted.xlsx")

# Show first 5 rows
df.head()
# Out:
#                                            photourl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        longname  \
# 0                  Lionel Messi
# 1  C. Ronaldo Dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar Da Silva Santos Jr.
#
#                                            playerurl nationality positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  Rw St Cf
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     St Lw
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        Gk
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    Cam Cm
# ...

# %%
import pandas as pd

# Load the formatted Excel file
df = pd.read_excel("fifa21_cleaned_formatted.xlsx")

# Show first 5 rows
df.head()
# Out:
#                                            photourl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        longname  \
# 0                  Lionel Messi
# 1  C. Ronaldo Dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar Da Silva Santos Jr.
#
#                                            playerurl nationality positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  Rw St Cf
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     St Lw
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        Gk
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    Cam Cm
# ...

# %%
# Count missing values per column
print(df.isnull().sum())
# Out:
# photourl        0
# longname        0
# playerurl       0
# nationality     0
# positions       0
#                ..
# dri             0
# def             0
# phy             0
# hits            0
# clean_status    0
# Length: 78, dtype: int64

# %%
# Count duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# Look for non-ASCII characters in text columns
text_cols = df.select_dtypes(include=['object']).columns
for col in text_cols:
    weird = df[col].apply(lambda x: any(ord(c) > 127 for c in str(x)))
    if weird.any():
        print(f"Column {col} has non-standard characters")
# Out:
# Column longname has non-standard characters
# Column nationality has non-standard characters
# Column name has non-standard characters
# Column team_&_contract has non-standard characters
# Column value has non-standard characters
# Column wage has non-standard characters
# Column release_clause has non-standard characters
# Column w/f has non-standard characters
# Column sm has non-standard characters
# Column ir has non-standard characters

# %%
# Summary of numeric columns
print(df.describe())
# Out:
#                 age          ↓ova           pot             id  height  \
# count  18978.000000  18978.000000  18978.000000   18978.000000     0.0
# mean      25.194225     65.718042     71.135789  226403.457477     NaN
# std        4.710618      6.968701      6.114189   27141.767404     NaN
# min       16.000000     47.000000     47.000000      41.000000     NaN
# 25%       21.000000     61.000000     67.000000  210134.500000     NaN
# 50%       25.000000     66.000000     71.000000  232421.000000     NaN
# 75%       29.000000     70.000000     75.000000  246922.750000     NaN
# max       53.000000     93.000000     95.000000  259216.000000     NaN
#
#        weight           bov        growth     attacking      crossing  ...  \
# count     0.0  18978.000000  18978.000000  18978.000000  18978.000000  ...
# mean      NaN     66.751080      5.417747    248.935610     49.687375  ...
# std       NaN      6.746785      5.663967     74.300567     18.131089  ...
# ...

# %%
df
# Out:
#                                                photourl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18973  https://cdn.sofifa.com/players/257/710/21_60.png
# 18974  https://cdn.sofifa.com/players/258/736/21_60.png
# 18975  https://cdn.sofifa.com/players/247/223/21_60.png
# 18976  https://cdn.sofifa.com/players/258/760/21_60.png
# 18977  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            longname  \
# 0                      Lionel Messi
# 1      C. Ronaldo Dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar Da Silva Santos Jr.
# ...                             ...
# ...

# %%
import pandas as pd

# Load your Excel file
df = pd.read_excel("fifa21_cleaned_formatted.xlsx")

# 1. Show column names
print("Columns:", df.columns.tolist())

# 2. Missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# 3. Duplicate rows
print("\nDuplicate rows:", df.duplicated().sum())

# 4. Numeric column types
numeric_cols = ['age','height','weight','pot']
if 'â†“ova' in df.columns:
    df.rename(columns={'â†“ova':'overall'}, inplace=True)
numeric_cols.append('overall')
print("\nNumeric column types:")
print(df[numeric_cols].dtypes)

# 5. Sample text values
print("\nSample nationalities:", df['nationality'].unique()[:10])
print("Sample positions:", df['positions'].unique()[:10])

# 6. Non-standard characters
text_cols = df.select_dtypes(include=['object']).columns
for col in text_cols:
    weird = df[col].apply(lambda x: any(ord(c) > 127 for c in str(x)))
    if weird.any():
        print(f"⚠️ Column {col} has non-standard characters")

# 7. Summary stats
print("\nSummary stats:")
print(df.describe())
# Out:
# Columns: ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'clean_status']
#
# Missing values per column:
# photourl        0
# ...

# %%
df.rename(columns={'â†“ova': 'overall'}, inplace=True)

# %%
print(df[['age','height','weight','pot','overall']].dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1867626106.py in <cell line: 0>()
# ----> 1 print(df[['age','height','weight','pot','overall']].dtypes)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
df.rename(columns={'â†“ova': 'overall'}, inplace=True)

# %%
# Step 1: Print all column names to find the correct one
print(df.columns.tolist())
# Out:
# ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'clean_status']

# %%
df.rename(columns={'â†“ova': 'overall'}, inplace=True)

# %%
print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1918544548.py in <cell line: 0>()
# ----> 1 print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
#       2 print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1918544548.py in <cell line: 0>()
# ----> 1 print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
#       2 print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
df.rename(columns={'ã†ova': 'overall'}, inplace=True)

# %%
print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1918544548.py in <cell line: 0>()
# ----> 1 print(df[['age', 'height', 'weight', 'pot', 'overall']].dtypes)
#       2 print(df[['age', 'height', 'weight', 'pot', 'overall']].describe())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
print(df.columns.tolist())
# Out:
# ['photourl', 'longname', 'playerurl', 'nationality', 'positions', 'name', 'age', '↓ova', 'pot', 'team_&_contract', 'id', 'height', 'weight', 'foot', 'bov', 'bp', 'growth', 'joined', 'loan_date_end', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'hits', 'clean_status']

# %%
summary = {
    "Total Players": len(df),
    "Average Age": round(df['age'].mean(), 1),
    "Average Height (cm)": round(df['height'].mean(), 1),
    "Average Weight (kg)": round(df['weight'].mean(), 1),
    "Average Potential": round(df['pot'].mean(), 1),
    "Average Overall": round(df['ova'].mean(), 1),
    "Unique Nationalities": df['nationality'].nunique(),
    "Unique Positions": df['positions'].nunique()
}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ova'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1565103125.py in <cell line: 0>()
#       5     "Average Weight (kg)": round(df['weight'].mean(), 1),
# ...

# %%
summary = {
    "Total Players": len(df),
    "Average Age": round(df['age'].mean(), 1),
    "Average Height (cm)": round(df['height'].mean(), 1),
    "Average Weight (kg)": round(df['weight'].mean(), 1),
    "Average Potential": round(df['pot'].mean(), 1),
    "Average Overall": round(df['ova'].mean(), 1),
    "Unique Nationalities": df['nationality'].nunique(),
    "Unique Positions": df['positions'].nunique()
}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ova'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1565103125.py in <cell line: 0>()
#       5     "Average Weight (kg)": round(df['weight'].mean(), 1),
# ...

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'photourl'
# 'longname'
# 'playerurl'
# 'nationality'
# 'positions'
# 'name'
# 'age'
# '↓ova'
# 'pot'
# 'team_&_contract'
# 'id'
# 'height'
# 'weight'
# 'foot'
# 'bov'
# 'bp'
# 'growth'
# 'joined'
# 'loan_date_end'
# 'value'
# 'wage'
# 'release_clause'
# 'attacking'
# 'crossing'
# 'finishing'
# 'heading_accuracy'
# 'short_passing'
# 'volleys'
# 'skill'
# 'dribbling'
# 'curve'
# 'fk_accuracy'
# 'long_passing'
# 'ball_control'
# 'movement'
# 'acceleration'
# 'sprint_speed'
# 'agility'
# 'reactions'
# 'balance'
# 'power'
# 'shot_power'
# 'jumping'
# 'stamina'
# 'strength'
# 'long_shots'
# 'mentality'
# 'aggression'
# 'interceptions'
# 'positioning'
# 'vision'
# 'penalties'
# 'composure'
# 'defending'
# 'marking'
# 'standing_tackle'
# 'sliding_tackle'
# 'goalkeeping'
# 'gk_diving'
# 'gk_handling'
# 'gk_kicking'
# 'gk_positioning'
# 'gk_reflexes'
# 'total_stats'
# 'base_stats'
# 'w/f'
# 'sm'
# 'a/w'
# 'd/w'
# 'ir'
# 'pac'
# 'sho'
# 'pas'
# 'dri'
# 'def'
# 'phy'
# 'hits'
# 'clean_status'

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.chart import BarChart, PieChart, Reference

# Load cleaned Excel file
df = pd.read_excel("fifa21_cleaned_formatted.xlsx")
wb = load_workbook("fifa21_cleaned_formatted.xlsx")
ws_summary = wb.create_sheet("Summary")

# Summary stats
summary = {
    "Total Players": len(df),
    "Average Age": round(df['age'].mean(), 1),
    "Average Height (cm)": round(df['height'].mean(), 1),
    "Average Weight (kg)": round(df['weight'].mean(), 1),
    "Average Potential": round(df['pot'].mean(), 1),
    "Average Overall": round(df['↓ova'].mean(), 1),
    "Unique Nationalities": df['nationality'].nunique(),
    "Unique Positions": df['positions'].nunique()
}

for key, value in summary.items():
    ws_summary.append([key, value])

# Top 10 Positions
ws_summary.append([])
ws_summary.append(["Top 10 Positions", "Count"])
top_positions = df['positions'].value_counts().head(10)
for pos, count in top_positions.items():
    ws_summary.append([pos, count])

bar = BarChart()
bar.title = "Top 10 Positions"
bar.x_axis.title = "Position"
bar.y_axis.title = "Count"
data = Reference(ws_summary, min_col=2, min_row=len(summary)+3, max_row=len(summary)+12)
cats = Reference(ws_summary, min_col=1, min_row=len(summary)+4, max_row=len(summary)+12)
bar.add_data(data, titles_from_data=True)
bar.set_categories(cats)
ws_summary.add_chart(bar, "E5")

# Top 10 Nationalities
ws_summary.append([])
ws_summary.append(["Top 10 Nationalities", "Count"])
top_nations = df['nationality'].value_counts().head(10)
for nat, count in top_nations.items():
    ws_summary.append([nat, count])

start_row = ws_summary.max_row - 9
pie = PieChart()
pie.title = "Top 10 Nationalities"
data = Reference(ws_summary, min_col=2, min_row=start_row, max_row=start_row+9)
cats = Reference(ws_summary, min_col=1, min_row=start_row, max_row=start_row+9)
pie.add_data(data, titles_from_data=False)
pie.set_categories(cats)
ws_summary.add_chart(pie, f"E20")

# Save final file
wb.save("fifa21_cleaned_with_summary_and_charts.xlsx")

# %%
from google.colab import files
files.download("fifa21_cleaned_with_summary_and_charts.xlsx")
